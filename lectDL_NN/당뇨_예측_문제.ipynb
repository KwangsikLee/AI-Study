# %% [markdown]
# **1단계**: 데이터 탐색 및 전처리
#
# 실제 데이터 로딩
#
# 결측값 탐지 및 처리 (0값 → NaN 변환)
#
# 이상치 탐지
#
# 데이터 시각화
#
#
# **2단계**: 모델 구현
#
# 로지스틱 회귀, 랜덤 포레스트, SVM, XGBoost
#
# 클래스 불균형 처리 (class_weight='balanced')
#
#
#
# **3단계**: ROC/AUC 분석
#
# ROC 곡선 시각화
#
# AUC 계산 및 비교

# %%
# 1. 데이터 다운로드 및 불러오기
import pandas as pd

url = "https://raw.githubusercontent.com/plotly/datasets/master/diabetes.csv"
df = pd.read_csv(url)
# print(df.head())

df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# | 컬럼명                          | 설명                               |
# | ---------------------------- | -------------------------------- |
# | **Pregnancies**              | 임신 횟수 (과거 임신한 총 횟수)              |
# | **Glucose**                  | 경구 포도당 내성 검사에서 측정된 혈당 농도         |
# | **BloodPressure**            | 혈압 (mm Hg, 이완기 혈압)               |
# | **SkinThickness**            | 팔 삼두근 피부 두께(mm)                  |
# | **Insulin**                  | 혈중 인슐린 농도 (2시간 기준, 단위: μU/mL)    |
# | **BMI**                      | 체질량지수 (BMI = 체중(kg) / \[신장(m)]²) |
# | **DiabetesPedigreeFunction** | 당뇨병 가족력 함수 (유전적 요인)              |
# | **Age**                      | 나이 (연령)                          |
# | **Outcome**                  | 당뇨병 발병 여부 (0: 비당뇨, 1: 당뇨병)       |
