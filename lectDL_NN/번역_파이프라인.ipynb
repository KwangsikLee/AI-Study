# %%
# 1. 설치 (Colab 한정: transformers 최신 버전)
# !pip install -U transformers sentencepiece
# Out:
# Requirement already satisfied: transformers in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (4.53.3)
# Requirement already satisfied: sentencepiece in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (0.2.0)
# Requirement already satisfied: filelock in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from transformers) (0.33.4)
# Requirement already satisfied: numpy>=1.17 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.7.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from requests->transformers) (2025.7.14)

# %%
# !pip uninstall -y keras
# !pip install tf-keras
# Out:
# WARNING: Skipping keras as it is not installed.
# Requirement already satisfied: tf-keras in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (2.19.0)
# Requirement already satisfied: tensorflow<2.20,>=2.19 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tf-keras) (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (4.25.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.32.4)
# Requirement already satisfied: setuptools in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.73.1)
# Requirement already satisfied: tensorboard~=2.19.0 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.19.0)
# Collecting keras>=3.5.0 (from tensorflow<2.20,>=2.19->tf-keras)
#   Using cached keras-3.10.0-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.37.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (2025.7.14)
# Requirement already satisfied: markdown>=2.6.8 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow<2.20,>=2.19->tf-keras) (0.45.1)
# Requirement already satisfied: rich in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (14.0.0)
# Requirement already satisfied: namex in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (0.1.0)
# Requirement already satisfied: optree in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (0.1.2)
# Using cached keras-3.10.0-py3-none-any.whl (1.4 MB)
# Installing collected packages: keras
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-macos 2.16.2 requires tensorflow==2.16.2; platform_system == "Darwin" and platform_machine == "arm64", but you have tensorflow 2.19.0 which is incompatible.
# Successfully installed keras-3.10.0

# %%
# !pip install torch --upgrade
# Out:
# Requirement already satisfied: torch in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (2.5.1)
# Collecting torch
#   Downloading torch-2.7.1-cp311-none-macosx_11_0_arm64.whl.metadata (29 kB)
# Requirement already satisfied: filelock in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from torch) (4.14.1)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from torch) (2025.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages (from jinja2->torch) (3.0.2)
# Downloading torch-2.7.1-cp311-none-macosx_11_0_arm64.whl (68.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 MB 42.9 MB/s eta 0:00:00a 0:00:01
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Installing collected packages: sympy, torch
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1━━━━━ 0/2 [sympy]
#   Attempting uninstall: torch━━━━━━━━━━━━━━━━━━━ 0/2 [sympy]
#     Found existing installation: torch 2.5.1 0/2 [sympy]
#     Uninstalling torch-2.5.1:━━━━━━━━━━━━━━━ 0/2 [sympy]
#       Successfully uninstalled torch-2.5.1━━━━━━━━━━━━━━━━━━━ 1/2 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [torch]32m1/2 [torch]
# Successfully installed sympy-1.14.0 torch-2.7.1

# %%
# 2. 라이브러리 import
from transformers import pipeline

# 3. 번역 파이프라인 로드 (Helsinki-NLP 사전학습모델 사용)
translator = pipeline("translation", model="Helsinki-NLP/opus-mt-ko-en")

# 4. 번역 함수 정의
def translate_korean_to_english(text):
    result = translator(text)
    return result[0]['translation_text']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 5
#       2 from transformers import pipeline
#       4 # 3. 번역 파이프라인 로드 (Helsinki-NLP 사전학습모델 사용)
# ----> 5 translator = pipeline("translation", model="Helsinki-NLP/opus-mt-ko-en")
#       7 # 4. 번역 함수 정의
#       8 def translate_korean_to_english(text):
#
# File ~/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/pipelines/__init__.py:1030, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1028 if isinstance(model, str) or framework is None:
#    1029     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# -> 1030     framework, model = infer_framework_load_model(
#    1031         adapter_path if adapter_path is not None else model,
#    1032         model_classes=model_classes,
#    1033         config=config,
#    1034         framework=framework,
#    1035         task=task,
#    1036         **hub_kwargs,
#    1037         **model_kwargs,
#    1038     )
#    1040 model_config = model.config
#    1041 hub_kwargs["_commit_hash"] = model.config._commit_hash
#
# File ~/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/pipelines/base.py:332, in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     330         for class_name, trace in all_traceback.items():
#     331             error += f"while loading with {class_name}, an error is thrown:\n{trace}\n"
# --> 332         raise ValueError(
#     333             f"Could not load model {model} with any of the following classes: {class_tuple}. See the original errors:\n\n{error}\n"
#     334         )
#     336 if framework is None:
#     337     framework = infer_framework(model.__class__)
#
# ValueError: Could not load model Helsinki-NLP/opus-mt-ko-en with any of the following classes: (<class 'transformers.models.auto.modeling_auto.AutoModelForSeq2SeqLM'>, <class 'transformers.models.auto.modeling_tf_auto.TFAutoModelForSeq2SeqLM'>, <class 'transformers.models.marian.modeling_marian.MarianMTModel'>, <class 'transformers.models.marian.modeling_tf_marian.TFMarianMTModel'>). See the original errors:
#
# while loading with AutoModelForSeq2SeqLM, an error is thrown:
# Traceback (most recent call last):
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/pipelines/base.py", line 292, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/models/auto/auto_factory.py", line 600, in from_pretrained
#     return model_class.from_pretrained(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/modeling_utils.py", line 311, in _wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/modeling_utils.py", line 4747, in from_pretrained
#     config, torch_dtype, dtype_orig = _get_torch_dtype(
#                                       ^^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/modeling_utils.py", line 1345, in _get_torch_dtype
#     state_dict = load_state_dict(
#                  ^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/modeling_utils.py", line 556, in load_state_dict
#     check_torch_load_is_safe()
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/utils/import_utils.py", line 1517, in check_torch_load_is_safe
#     raise ValueError(
# ValueError: Due to a serious vulnerability issue in `torch.load`, even with `weights_only=True`, we now require users to upgrade torch to at least v2.6 in order to use the function. This version restriction does not apply when loading files with safetensors.
# See the vulnerability report here https://nvd.nist.gov/vuln/detail/CVE-2025-32434
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/pipelines/base.py", line 310, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **fp32_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/models/auto/auto_factory.py", line 600, in from_pretrained
#     return model_class.from_pretrained(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/modeling_utils.py", line 311, in _wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/modeling_utils.py", line 4839, in from_pretrained
#     ) = cls._load_pretrained_model(
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/modeling_utils.py", line 5105, in _load_pretrained_model
#     load_state_dict(checkpoint_files[0], map_location="meta", weights_only=weights_only).keys()
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/modeling_utils.py", line 556, in load_state_dict
#     check_torch_load_is_safe()
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/utils/import_utils.py", line 1517, in check_torch_load_is_safe
#     raise ValueError(
# ValueError: Due to a serious vulnerability issue in `torch.load`, even with `weights_only=True`, we now require users to upgrade torch to at least v2.6 in order to use the function. This version restriction does not apply when loading files with safetensors.
# See the vulnerability report here https://nvd.nist.gov/vuln/detail/CVE-2025-32434
#
# while loading with TFAutoModelForSeq2SeqLM, an error is thrown:
# Traceback (most recent call last):
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/pipelines/base.py", line 310, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **fp32_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/models/auto/auto_factory.py", line 600, in from_pretrained
#     return model_class.from_pretrained(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/modeling_tf_utils.py", line 2935, in from_pretrained
#     model = cls(config, *model_args, **model_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/models/marian/modeling_tf_marian.py", line 1369, in __init__
#     super().__init__(config, *inputs, **kwargs)
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/modeling_tf_utils.py", line 1190, in __init__
#     super().__init__(*inputs, **kwargs)
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/tensorflow/python/trackable/base.py", line 204, in _method_wrapper
#     result = method(self, *args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/tf_keras/src/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/tf_keras/src/utils/generic_utils.py", line 513, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'torch_dtype')
#
# while loading with MarianMTModel, an error is thrown:
# Traceback (most recent call last):
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/pipelines/base.py", line 292, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/modeling_utils.py", line 311, in _wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/modeling_utils.py", line 4747, in from_pretrained
#     config, torch_dtype, dtype_orig = _get_torch_dtype(
#                                       ^^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/modeling_utils.py", line 1345, in _get_torch_dtype
#     state_dict = load_state_dict(
#                  ^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/modeling_utils.py", line 556, in load_state_dict
#     check_torch_load_is_safe()
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/utils/import_utils.py", line 1517, in check_torch_load_is_safe
#     raise ValueError(
# ValueError: Due to a serious vulnerability issue in `torch.load`, even with `weights_only=True`, we now require users to upgrade torch to at least v2.6 in order to use the function. This version restriction does not apply when loading files with safetensors.
# See the vulnerability report here https://nvd.nist.gov/vuln/detail/CVE-2025-32434
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/pipelines/base.py", line 310, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **fp32_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/modeling_utils.py", line 311, in _wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/modeling_utils.py", line 4839, in from_pretrained
#     ) = cls._load_pretrained_model(
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/modeling_utils.py", line 5105, in _load_pretrained_model
#     load_state_dict(checkpoint_files[0], map_location="meta", weights_only=weights_only).keys()
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/modeling_utils.py", line 556, in load_state_dict
#     check_torch_load_is_safe()
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/utils/import_utils.py", line 1517, in check_torch_load_is_safe
#     raise ValueError(
# ValueError: Due to a serious vulnerability issue in `torch.load`, even with `weights_only=True`, we now require users to upgrade torch to at least v2.6 in order to use the function. This version restriction does not apply when loading files with safetensors.
# See the vulnerability report here https://nvd.nist.gov/vuln/detail/CVE-2025-32434
#
# while loading with TFMarianMTModel, an error is thrown:
# Traceback (most recent call last):
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/pipelines/base.py", line 310, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **fp32_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/modeling_tf_utils.py", line 2935, in from_pretrained
#     model = cls(config, *model_args, **model_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/models/marian/modeling_tf_marian.py", line 1369, in __init__
#     super().__init__(config, *inputs, **kwargs)
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/transformers/modeling_tf_utils.py", line 1190, in __init__
#     super().__init__(*inputs, **kwargs)
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/tensorflow/python/trackable/base.py", line 204, in _method_wrapper
#     result = method(self, *args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/tf_keras/src/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/Users/kwangsiklee/miniforge3/envs/llmenv/lib/python3.11/site-packages/tf_keras/src/utils/generic_utils.py", line 513, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'torch_dtype')

# %%
# 5. 직접 한글 입력받아 번역 실행
input_text = input("번역할 한글 문장을 입력하세요: ")
translation = translate_korean_to_english(input_text)
print("번역 결과:", translation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # 5. 직접 한글 입력받아 번역 실행
#       2 input_text = input("번역할 한글 문장을 입력하세요: ")
# ----> 3 translation = translate_korean_to_english(input_text)
#       4 print("번역 결과:", translation)
#
# NameError: name 'translate_korean_to_english' is not defined
