# %%
# 나눔고딕 폰트 설치 및 설정
# !apt-get update -qq
# !apt-get install fonts-nanum -qq
# !fc-cache -fv
# !rm ~/.cache/matplotlib -rf

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np

import matplotlib.font_manager as fm

# 폰트 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path, size=10)
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# ...

# %%
# ============================================================================
# 예제 2: 중급 CNN을 이용한 CIFAR-10 컬러 이미지 분류
# ============================================================================

# CIFAR-10 클래스 이름
CLASS_NAMES = ['비행기', '자동차', '새', '고양이', '사슴',
               '개', '개구리', '말', '배', '트럭']

def load_and_preprocess_cifar10():
    """CIFAR-10 데이터를 로드하고 전처리합니다."""
    print(" CIFAR-10 데이터 로딩 중...")

    # CIFAR-10 데이터셋 로드
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

    print(f"훈련 데이터 형태: {x_train.shape}")
    print(f"테스트 데이터 형태: {x_test.shape}")
    print(f"이미지 크기: {x_train.shape[1:3]}, 채널: {x_train.shape[3]}")

    # 정규화 (0-255 -> 0-1)
    x_train = x_train.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0

    # 원-핫 인코딩
    y_train = tf.keras.utils.to_categorical(y_train, 10)
    y_test = tf.keras.utils.to_categorical(y_test, 10)

    return (x_train, y_train), (x_test, y_test)

def visualize_cifar10_samples(x_data, y_data, num_samples=10):
    """CIFAR-10 샘플 이미지들을 시각화합니다."""
    plt.figure(figsize=(15, 3))
    for i in range(num_samples):
        plt.subplot(2, 5, i + 1)
        plt.imshow(x_data[i])
        plt.title(f'{CLASS_NAMES[np.argmax(y_data[i])]}')
        plt.axis('off')
    plt.suptitle('CIFAR-10 샘플 이미지들', fontsize=16)
    plt.tight_layout()
    plt.show()

def create_improved_cnn():
    """개선된 CNN 모델을 생성합니다."""
    print(" 개선된 CNN 모델 구성 중...")

    model = models.Sequential([
        # 첫 번째 Conv Block
        layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
        layers.BatchNormalization(),
        layers.Conv2D(32, (3, 3), activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # 두 번째 Conv Block
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.BatchNormalization(),
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # 세 번째 Conv Block
        layers.Conv2D(128, (3, 3), activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.25),

        # Fully Connected Layers
        layers.Flatten(),
        layers.Dense(512, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(10, activation='softmax')
    ])

    return model

def create_data_augmentation():
    """데이터 증강을 위한 ImageDataGenerator를 생성합니다."""
    print(" 데이터 증강 설정 중...")

    datagen = ImageDataGenerator(
        rotation_range=15,          # 15도 회전
        width_shift_range=0.1,      # 가로 이동
        height_shift_range=0.1,     # 세로 이동
        horizontal_flip=True,       # 좌우 반전
        zoom_range=0.1,             # 확대/축소
        shear_range=0.1,            # 전단 변환
        fill_mode='nearest'         # 빈 공간 채우기
    )

    return datagen

def visualize_data_augmentation(datagen, x_train):
    """데이터 증강 예시를 시각화합니다."""
    # 원본 이미지 선택
    sample_img = x_train[0:1]  # 첫 번째 이미지

    plt.figure(figsize=(15, 3))

    # 원본 이미지
    plt.subplot(1, 6, 1)
    plt.imshow(sample_img[0])
    plt.title('원본')
    plt.axis('off')

    # 증강된 이미지들
    aug_iter = datagen.flow(sample_img, batch_size=1)
    for i in range(5):
        plt.subplot(1, 6, i + 2)
        aug_img = next(aug_iter)[0]
        plt.imshow(aug_img)
        plt.title(f'증강 {i+1}')
        plt.axis('off')

    plt.suptitle('데이터 증강 예시', fontsize=16)
    plt.tight_layout()
    plt.show()

def train_with_callbacks(model, train_data, validation_data, datagen, epochs=20):
    """콜백을 사용하여 모델을 훈련합니다."""
    print(f"\n 모델 훈련 시작 (에포크: {epochs})...")

    # 모델 컴파일
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    # 콜백 설정
    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy',
            patience=5,
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=3,
            min_lr=0.0001
        )
    ]

    # 데이터 증강을 사용한 훈련
    history = model.fit(
        datagen.flow(train_data[0], train_data[1], batch_size=32),
        steps_per_epoch=len(train_data[0]) // 32,
        epochs=epochs,
        validation_data=validation_data,
        callbacks=callbacks,
        verbose=1
    )

    return history

def create_confusion_matrix(model, test_data):
    """혼동 행렬을 생성하고 시각화합니다."""
    from sklearn.metrics import confusion_matrix, classification_report
    import seaborn as sns

    # 예측 수행
    y_pred = model.predict(test_data[0])
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true_classes = np.argmax(test_data[1], axis=1)

    # 혼동 행렬 생성
    cm = confusion_matrix(y_true_classes, y_pred_classes)

    # 혼동 행렬 시각화
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
    plt.title('혼동 행렬 (Confusion Matrix)')
    plt.xlabel('예측 레이블')
    plt.ylabel('실제 레이블')
    plt.xticks(rotation=45)
    plt.yticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # 분류 리포트 출력
    print("\n 분류 리포트:")
    report = classification_report(y_true_classes, y_pred_classes,
                                 target_names=CLASS_NAMES)
    print(report)

def analyze_predictions(model, test_data, num_samples=10):
    """예측 결과를 분석하고 시각화합니다."""
    predictions = model.predict(test_data[0][:num_samples])

    fig, axes = plt.subplots(2, 5, figsize=(15, 8))
    for i in range(num_samples):
        ax = axes[i//5, i%5]
        ax.imshow(test_data[0][i])

        # 예측 결과
        pred_probs = predictions[i]
        true_label = np.argmax(test_data[1][i])
        pred_label = np.argmax(pred_probs)
        confidence = np.max(pred_probs)

        # 색상 설정 (정답: 초록, 오답: 빨강)
        color = 'green' if true_label == pred_label else 'red'

        ax.set_title(f'실제: {CLASS_NAMES[true_label]}\n'
                    f'예측: {CLASS_NAMES[pred_label]}\n'
                    f'신뢰도: {confidence:.2f}',
                    color=color, fontsize=10)
        ax.axis('off')

    plt.suptitle('CIFAR-10 예측 결과 분석', fontsize=16)
    plt.tight_layout()
    plt.show()

# ============================================================================
# 메인 실행 함수
# ============================================================================

def main():
    """CNN 예제 2의 메인 실행 함수입니다."""
    print(" CNN 예제 2: CIFAR-10 컬러 이미지 분류")
    print("=" * 50)

    # 1. 데이터 로드 및 전처리
    (x_train, y_train), (x_test, y_test) = load_and_preprocess_cifar10()

    # 2. 샘플 데이터 시각화
    visualize_cifar10_samples(x_train, y_train)

    # 3. 데이터 증강 설정
    datagen = create_data_augmentation()
    datagen.fit(x_train)

    # 4. 데이터 증강 예시 시각화
    visualize_data_augmentation(datagen, x_train)

    # 5. 모델 생성
    model = create_improved_cnn()
    model.summary()

    # 6. 모델 훈련
    history = train_with_callbacks(model, (x_train, y_train),
                                 (x_test, y_test), datagen, epochs=20)

    # 7. 훈련 과정 시각화
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

    # 정확도
    ax1.plot(history.history['accuracy'], label='accuracy')
    ax1.plot(history.history['val_accuracy'], label='val_accuracy')
    ax1.set_title('model accuracy')
    ax1.set_xlabel('epoch')
    ax1.set_ylabel('accuracy')
    ax1.legend()
    ax1.grid(True)

    # 손실
    ax2.plot(history.history['loss'], label='loss')
    ax2.plot(history.history['val_loss'], label='val_loss')
    ax2.set_title('model loss')
    ax2.set_xlabel('epoch')
    ax2.set_ylabel('epoch')
    ax2.legend()
    ax2.grid(True)

    plt.tight_layout()
    plt.show()

    # 8. 모델 평가
    test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
    print(f"\n test_accuracy: {test_accuracy:.4f}")

    # 9. 혼동 행렬 생성
    create_confusion_matrix(model, (x_test, y_test))

    # 10. 예측 결과 분석
    analyze_predictions(model, (x_test, y_test))

    return model

# 실행
if __name__ == "__main__":
    trained_model = main()
# Out:
# 🎯 CNN 예제 2: CIFAR-10 컬러 이미지 분류
# ...
# 📁 CIFAR-10 데이터 로딩 중...
# 훈련 데이터 형태: (50000, 32, 32, 3)
# 테스트 데이터 형태: (10000, 32, 32, 3)
# 이미지 크기: (32, 32), 채널: 3
# 🔄 데이터 증강 설정 중...
# 🏗️ 개선된 CNN 모델 구성 중...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...
